# %% [markdown]
# # Exploratory Analysis
#
# Interpret class balance, distributions, and correlations by anonymous well.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))
import pandas as pd
import numpy as np
from qm640_pipeline import *

# %%
df = load_processed(ROOT)
df.groupby("Well_ID")["NTG"].agg(["count","mean"])
# Out:
#          count      mean
# Well_ID
# W01       1481  0.307225
# W02       1778  0.287402
# W03       2011  0.213327
# W04         99  0.747475
# W05       1881  0.604466
# W06       1218  0.599343

# %%
df[["MD","TVDSS","ZONE","VSH","SW","RT","PHIT","NTG","K"]].corr(method="spearman").round(3)
# Out:
#           MD  TVDSS   ZONE    VSH     SW     RT   PHIT    NTG      K
# MD     1.000  1.000  0.767  0.238  0.655 -0.238 -0.390 -0.195 -0.377
# TVDSS  1.000  1.000  0.771  0.238  0.659 -0.238 -0.396 -0.200 -0.383
# ZONE   0.767  0.771  1.000  0.079  0.623 -0.079 -0.468 -0.208 -0.433
# VSH    0.238  0.238  0.079  1.000  0.378 -1.000 -0.461 -0.562 -0.504
# SW     0.655  0.659  0.623  0.378  1.000 -0.378 -0.674 -0.541 -0.671
# RT    -0.238 -0.238 -0.079 -1.000 -0.378  1.000  0.461  0.562  0.504
# PHIT  -0.390 -0.396 -0.468 -0.461 -0.674  0.461  1.000  0.749  0.962
# NTG   -0.195 -0.200 -0.208 -0.562 -0.541  0.562  0.749  1.000  0.846
# K     -0.377 -0.383 -0.433 -0.504 -0.671  0.504  0.962  0.846  1.000

# %%
from IPython.display import Image, display
display(Image(filename=str(ROOT / "figures" / "pay_share_by_well.png")))
display(Image(filename=str(ROOT / "figures" / "spearman_correlation_matrix.png")))
