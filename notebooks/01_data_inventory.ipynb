# %% [markdown]
# # Data Inventory
#
# Verify schema, row counts, groups, ranges, target balance, and raw/processed separation.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))
import pandas as pd
import numpy as np
from qm640_pipeline import *

# %%
df = load_processed(ROOT)
inventory = data_inventory(df)
inventory
# Out:
# {'rows': 8468,
#  'columns': ['Well_ID',
#   'MD',
#   'TVDSS',
#   'ZONE',
#   'VSH',
#   'SW',
#   'RT',
#   'PHIT',
#   'NTG',
#   'K'],
#  'well_counts': {'W01': 1481,
#   'W02': 1778,
#   'W03': 2011,
#   'W04': 99,
#   'W05': 1881,
#   'W06': 1218},
#  'target_counts': {0: 5132, 1: 3336},
#  'missing_values': {'Well_ID': 0,
#   'MD': 0,
#   'TVDSS': 0,
#   'ZONE': 0,
#   'VSH': 0,
#   'SW': 0,
#   'RT': 0,
#   'PHIT': 0,
#   'NTG': 0,
#   'K': 0},
#  'exact_duplicate_rows': 0,
#  'duplicate_well_md': 0}

# %%
df.groupby("Well_ID").agg(N=("NTG","size"), Pay_Share=("NTG","mean"))
# Out:
#             N  Pay_Share
# Well_ID
# W01      1481   0.307225
# W02      1778   0.287402
# W03      2011   0.213327
# W04        99   0.747475
# W05      1881   0.604466
# W06      1218   0.599343

# %%
df.describe(include="all").T
# Out:
#           count unique  top  ...         50%         75%        max
# Well_ID    8468      6  W03  ...         NaN         NaN        NaN
# MD       8468.0    NaN  NaN  ...  2812.50525  3249.03435  4049.4278
# TVDSS    8468.0    NaN  NaN  ...  2727.18375   3163.0686    3971.28
# ZONE     8468.0    NaN  NaN  ...        11.0        12.0       14.0
# VSH      8468.0    NaN  NaN  ...      0.5686       0.673     0.9186
# SW       8468.0    NaN  NaN  ...         1.0         1.0        1.0
# RT       8468.0    NaN  NaN  ...      6.8781     8.47235    89.1335
# PHIT     8468.0    NaN  NaN  ...       0.156      0.1842     0.2911
# NTG      8468.0    NaN  NaN  ...         0.0         1.0        1.0
# K        8468.0    NaN  NaN  ...      0.7242     6.85035  1285.2279
#
# [10 rows x 11 columns]
