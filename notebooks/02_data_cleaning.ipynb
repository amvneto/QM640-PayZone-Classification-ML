# %% [markdown]
# # Data Cleaning
#
# Document actual cleaning evidence without treating repeated geological states as duplicate errors.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))
import pandas as pd
import numpy as np
from qm640_pipeline import *

# %%
df = load_processed(ROOT)
cleaning_summary(df)
# Out:
#                        Check  Count                         Treatment
# 0         Source missingness      0                 No raw imputation
# 1      Anonymous well groups      6  Retain W01-W06 for grouping only
# 2       Exact duplicate rows      0                        No removal
# 3  Duplicate Well_ID-MD keys      0                        No removal
# 4   Adjacent repeated states   6711               Retain and disclose
# 5   Consecutive state blocks   1757        Use as dependence evidence

# %%
raw = load_raw(ROOT)
reconstructed = assign_well_ids(raw)
(reconstructed.shape, reconstructed.Well_ID.value_counts().sort_index())
# Out:
# ((8468, 10),
#  Well_ID
#  W01    1481
#  W02    1778
#  W03    2011
#  W04      99
#  W05    1881
#  W06    1218
#  Name: count, dtype: int64)

# %%
assert reconstructed.drop(columns="Well_ID").equals(raw)
print("Raw values preserved; only anonymous grouping was added.")
# Out:
# Raw values preserved; only anonymous grouping was added.
