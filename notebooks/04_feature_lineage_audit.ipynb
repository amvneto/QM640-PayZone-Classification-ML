# %% [markdown]
# # Feature-Lineage Audit
#
# Review feature origin, leakage risk, and the K-only target-proxy test.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))
import pandas as pd
import numpy as np
from qm640_pipeline import *

# %%
lineage = pd.read_csv(ROOT / "data" / "dictionary" / "feature_lineage_register.csv")
lineage
# Out:
#    Feature  ...                                   Required_Control
# 0  Well_ID  ...   Use for leave-one-well-out splits; never enter X
# 1       MD  ...  Check monotonicity and exclude from transporta...
# 2    TVDSS  ...              Quantify correlation with MD; exclude
# 3     ZONE  ...  Ablation only unless independent lineage is de...
# 4      VSH  ...       Document derivation and compare with/without
# 5       SW  ...         Trace formula inputs before any future use
# 6       RT  ...               Do not use in primary classification
# 7     PHIT  ...  Test direction and threshold across held-out w...
# 8      NTG  ...  Describe task as reproduction of available ind...
# 9        K  ...                          Report K-only proxy audit
#
# [10 rows x 5 columns]

# %%
df = load_processed(ROOT)
k_proxy_audit(df)
# Out:
# {'Accuracy': 0.9965753424657534,
#  'Balanced_Accuracy': 0.9961779991439428,
#  'Precision': 0.9969942891493838,
#  'Sensitivity': 0.9943045563549161,
#  'Specificity': np.float64(0.9980514419329696),
#  'F1': 0.9956476061834009,
#  'MCC': 0.9928271423596778,
#  'ROC_AUC': 0.9982522263560937,
#  'PR_AUC': 0.9960599497954428,
#  'Brier': 0.0031304227868264155,
#  'TN': 5122,
#  'FP': 10,
#  'FN': 19,
#  'TP': 3317,
#  'Macro_Balanced_Accuracy': np.float64(0.9900976165320428)}

# %% [markdown]
# **Interpretation:** Near-perfect K-only performance is treated as target-proxy evidence, not as an acceptable predictive result.
