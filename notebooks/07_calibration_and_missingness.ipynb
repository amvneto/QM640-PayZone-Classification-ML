# %% [markdown]
# # Calibration and Missingness Sensitivity
#
# Review probability-quality and the fixed-seed controlled missingness experiment.

# %%
from pathlib import Path
import json
import pandas as pd
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

# %%
pd.read_csv(ROOT / "results" / "calibration_results.csv")
# Out:
#    Mean_Predicted_Probability  Observed_Pay_Frequency
# 0                    0.000816                0.028202
# 1                    0.005977                0.040189
# 2                    0.018702                0.020142
# 3                    0.056142                0.036643
# 4                    0.143004                0.051765
# 5                    0.310265                0.241420
# 6                    0.556193                0.635613
# 7                    0.869432                0.899289
# 8                    0.987669                0.988208
# 9                    0.999819                1.000000

# %%
pd.read_csv(ROOT / "results" / "missingness_sensitivity.csv")
# Out:
#                                             Scenario  ...     Brier
# 0  Controlled 5% missingness in selected predicto...  ...  0.075797
#
# [1 rows x 11 columns]

# %%
from IPython.display import Image, display
display(Image(filename=str(ROOT / "figures" / "calibration_curve.png")))

# %% [markdown]
# The simulated blank cells are a controlled sensitivity test and must not be described as naturally occurring missingness.
